# %%
import pandas as pd
import numpy as np
from sklearn.tree import DecisionTreeRegressor
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from scipy.stats import skew

# %%
train_path = 'data/Housing Prices Competition/train.csv'
test_path = 'data/Housing Prices Competition/test.csv'
sample_submission_path = 'data/Housing Prices Competition/sample_submission.csv'

train_data = pd.read_csv(train_path)
test_data = pd.read_csv(test_path)
sample_submission_data = pd.read_csv(sample_submission_path)

# %%
features = ['BsmtUnfSF', 'TotRmsAbvGrd', 'YearRemodAdd', 'LotFrontage', 'FullBath', 'YearBuilt', 'LotArea',
'GarageArea', 'GarageCars', '1stFlrSF', 'BsmtFinSF1', '2ndFlrSF', 'TotalBsmtSF', 'GrLivArea', 'OverallQual', 'Fireplaces', 
'OpenPorchSF', 'GarageYrBlt', 'MasVnrArea', 'WoodDeckSF', 'HalfBath']

cols = train_data[features].select_dtypes(include=['number']).columns

for col, has_nan in zip(features, train_data[features].isnull().any()):
    if has_nan:
        print(col)
        train_data[col].fillna(train_data[col].mode()[0])
# Out:
# LotFrontage
# GarageYrBlt
# MasVnrArea

# %%
numeric_cols = train_data.select_dtypes(include=['number']).columns
unique_cols = list(set(list(set(new_cols)) + list(set(numeric_cols))))
print(numeric_cols.to_list())
print(unique_cols)
# Out:
# ['Id', 'MSSubClass', 'LotFrontage', 'LotArea', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd', 'MasVnrArea', 'BsmtFinSF1', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'TotRmsAbvGrd', 'Fireplaces', 'GarageYrBlt', 'GarageCars', 'GarageArea', 'WoodDeckSF', 'OpenPorchSF', 'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'MiscVal', 'MoSold', 'YrSold', 'SalePrice', 'BsmtUnfSF 150', 'BsmtUnfSF 284', 'BsmtUnfSF 434', 'BsmtUnfSF 540', 'BsmtUnfSF 490', 'BsmtUnfSF 64', 'BsmtUnfSF 317', 'BsmtUnfSF 216', 'BsmtUnfSF 952', 'BsmtUnfSF 140', 'BsmtUnfSF 134', 'BsmtUnfSF 177', 'BsmtUnfSF 175', 'BsmtUnfSF 1494', 'BsmtUnfSF 520', 'BsmtUnfSF 832', 'BsmtUnfSF 426', 'BsmtUnfSF 0', 'BsmtUnfSF 468', 'BsmtUnfSF 525', 'BsmtUnfSF 1158', 'BsmtUnfSF 637', 'BsmtUnfSF 1777', 'BsmtUnfSF 200', 'BsmtUnfSF 204', 'BsmtUnfSF 1566', 'BsmtUnfSF 180', 'BsmtUnfSF 486', 'BsmtUnfSF 207', 'BsmtUnfSF 649', 'BsmtUnfSF 1228', 'BsmtUnfSF 1234', 'BsmtUnfSF 380', 'BsmtUnfSF 408', 'BsmtUnfSF 1117', 'BsmtUnfSF 1097', 'BsmtUnfSF 84', 'BsmtUnfSF 326', 'BsmtUnfSF 445', 'BsmtUnfSF 383', 'BsmtUnfSF 167', 'BsmtUnfSF 465', 'BsmtUnfSF 1296', 'BsmtUnfSF 83', 'BsmtUnfSF 1632', 'BsmtUnfSF 736', 'BsmtUnfSF 192', 'BsmtUnfSF 612', 'BsmtUnfSF 816', 'BsmtUnfSF 32', 'BsmtUnfSF 935', 'BsmtUnfSF 321', 'BsmtUnfSF 860', 'BsmtUnfSF 1410', 'BsmtUnfSF 148', 'BsmtUnfSF 217', 'BsmtUnfSF 530', 'BsmtUnfSF 1346', 'BsmtUnfSF 576', 'BsmtUnfSF 318', 'BsmtUnfSF 1143', 'BsmtUnfSF 1035', 'BsmtUnfSF 440', 'BsmtUnfSF 747', 'BsmtUnfSF 701', 'BsmtUnfSF 343', 'BsmtUnfSF 280', 'BsmtUnfSF 404', 'BsmtUnfSF 
SF 728', 'GrLivArea 848', 'LotArea 8158', 'LotArea 8294', 'WoodDeckSF 476', 'GrLivArea 1034', 'GrLivArea 1334', 'BsmtFinSF1 1416', 'MasVnrArea 370.0', 'BsmtFinSF1 312', 'LotArea 8530', 'LotArea 11457', 'BsmtFinSF1 548', '1stFlrSF 1146', 'GrLivArea 1743', 'WoodDeckSF 500', 'GrLivArea 1977', 'LotArea 14115', 'TotalBsmtSF 1145', 'TotalBsmtSF 2158', 'GrLivArea 841', 'WoodDeckSF 49', 'TotalBsmtSF 1396', 'LotArea 3696', 'MasVnrArea 160.0', 'BsmtUnfSF 61', 'GarageArea 445', 'GarageYrBlt 1937.0', 'MasVnrArea 306.0', '1stFlrSF 1040', 'GrLivArea 1394', 'BsmtUnfSF 626', 'LotArea 14559', 'BsmtUnfSF 261', 'GrLivArea 2002', 'GarageYrBlt 1934.0', 'LotArea 11694', 'LotArea 14303', 'GrLivArea 1114', '1stFlrSF 1444', 'GrLivArea 1389', 'BsmtUnfSF 190', 'BsmtUnfSF 352', '1stFlrSF 1097', 'GarageArea 800', 'LotArea 13693', 'LotArea 18000', 'LotArea 9042', 'GrLivArea 1652', 'LotArea 12085', 'LotFrontage 84.0', 'GrLivArea 1478', '1stFlrSF 802', 'GrLivArea 1218', 'LotArea 7264', 'MasVnrArea 142.0', 'YearBuilt 2005', 'LotArea 9819', 'GrLivArea 1383', 'LotArea 5250', 'GarageYrBlt 2001.0', 'GarageArea 432', '1stFlrSF 1486', 'TotalBsmtSF 1510', '1stFlrSF 1065', 'GrLivArea 1235', 'LotArea 9313', '1stFlrSF 1392', 'BsmtFinSF1 252', 'GarageArea 543', 'BsmtUnfSF 1686', 'LotArea 10120', '1stFlrSF 1122', 'LotArea 10625', 'TotalBsmtSF 792', 'BsmtUnfSF 554', 'LotArea 8393', 'OpenPorchSF 162', 'LotArea 17104', '1stFlrSF 1187', 'TotalBsmtSF 1041', 'GarageCars 3', 'BsmtUnfSF 251', 'GarageArea 645', 'BsmtFinSF1 456', 'GrLivArea 1365', 'GarageYrBlt 1914.0', 'GrLivArea 1382', 'GarageArea 471', 'BsmtUnfSF 447', 'TotalBsmtSF 1629', 'GrLivArea 1015', 'TotalBsmtSF 1108', 'LotArea 8755', '1stFlrSF 924', '1stFlrSF 1221', 'GrLivArea 981', 'BsmtFinSF1 251', '1stFlrSF 887', 'LotArea 6371', 'BsmtUnfSF 968', 'GrLivArea 796', 'GrLivArea 1094', 'GarageArea 512', 'TotalBsmtSF 1719', '1stFlrSF 1787', 'GrLivArea 930', 'MasVnrArea 74.0', 'GrLivArea 3608', 'LotArea 11988', 'BsmtFinSF1 282', 'BsmtFinSF1 1470', 'GrLivArea 1725', 'TotalBsmtSF 814', 'TotalBsmtSF 848', 'LotArea 8100', 'MasVnrArea 360.0', 'GarageYrBlt 1955.0', 'BsmtFinSF1 551', 'GarageArea 604', 'GrLivArea 1533', 'GrLivArea 1134', 'BsmtFinSF1 607', 'BsmtUnfSF 849', 'LotArea 115149', '1stFlrSF 1414', '1stFlrSF 1505', 'GarageArea 450', 'Bs ...
